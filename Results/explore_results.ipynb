# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load data

# %%
SL_AL_2500 = 'Results/Progress_results/SL_AL_correction_500_2500.csv'
SL_AL_5000 = 'Results/Progress_results/SL_AL_correction_1000_5000.csv'
SL_AL_10000 = 'Results/Progress_results/SL_AL_correction_2000_10000.csv'

AL_2500 = 'Results/Progress_results/AL_500_2500.csv'
AL_5000 = 'Results/Progress_results/AL_1000_5000.csv'
AL_10000 = 'Results/Progress_results/AL_2000_10000.csv'

AL_SL_parrel_2500 = 'Results/Progress_results/AL_SL_500_2500.csv'
AL_SL_parrel_5000 = 'Results/Progress_results/AL_SL_1000_5000.csv'
AL_SL_parrel_10000 = 'Results/Progress_results/AL_SL_2000_10000.csv'

AL_SL_hybrid_2500 = 'Results/Progress_results/SL_AL_correction_hybrid_500_2500.csv'
AL_SL_hybrid_5000 = 'Results/Progress_results/SL_AL_correction_hybrid_1000_5000.csv'
AL_SL_hybrid_10000 = 'Results/Progress_results/SL_AL_correction_hybrid_2000_10000.csv'

SL_AL_limited_2500 = 'Results/Progress_results/SL_AL_limited_first_500_2500.csv'
SL_AL_limited_5000 = 'Results/Progress_results/SL_AL_limited_first_1000_5000.csv'
SL_AL_limited_10000 = 'Results/Progress_results/SL_AL_limited_first_2000_10000.csv'

AL_random_2500 = 'Results/Progress_results/AL_random_500_2500.csv'
AL_random_5000 = 'Results/Progress_results/AL_random_1000_5000.csv'
AL_random_10000 = 'Results/Progress_results/AL_random_2000_10000.csv'

# %%
sl_al_2500_df = pd.read_csv(SL_AL_2500)
sl_al_5000_df = pd.read_csv(SL_AL_5000)
sl_al_10000_df = pd.read_csv(SL_AL_10000)

al_2500_df = pd.read_csv(AL_2500)
al_5000_df = pd.read_csv(AL_5000)
al_10000_df = pd.read_csv(AL_10000)

AL_SL_hybrid_2500_df = pd.read_csv(AL_SL_hybrid_2500)
AL_SL_hybrid_5000_df = pd.read_csv(AL_SL_hybrid_5000)
AL_SL_hybrid_10000_df = pd.read_csv(AL_SL_hybrid_10000)

sl_al_limited_2500_df = pd.read_csv(SL_AL_limited_2500)
sl_al_limited_5000_df = pd.read_csv(SL_AL_limited_5000)
sl_al_limited_10000_df = pd.read_csv(SL_AL_limited_10000)

al_random_2500_df = pd.read_csv(AL_random_2500)
al_random_5000_df = pd.read_csv(AL_random_5000) 
al_random_10000_df = pd.read_csv(AL_random_10000)

# %% [markdown]
# # Explore technique

# %%
sl_al_2500_grouped = sl_al_2500_df.groupby('Iteration').mean()
sl_al_5000_grouped = sl_al_5000_df.groupby('Iteration').mean()
sl_al_10000_grouped = sl_al_10000_df.groupby('Iteration').mean()

sl_al_2500_grouped.reset_index(inplace=True)
sl_al_5000_grouped.reset_index(inplace=True)
sl_al_10000_grouped.reset_index(inplace=True)

# %%
# Group all dataframes by 'Iteration' and calculate the mean
sl_al_2500_grouped = sl_al_2500_df.groupby('Iteration').mean()
sl_al_5000_grouped = sl_al_5000_df.groupby('Iteration').mean()
sl_al_10000_grouped = sl_al_10000_df.groupby('Iteration').mean()

al_2500_grouped = al_2500_df.groupby('Iteration').mean()
al_5000_grouped = al_5000_df.groupby('Iteration').mean()
al_10000_grouped = al_10000_df.groupby('Iteration').mean()

al_sl_hybrid_2500_grouped = AL_SL_hybrid_2500_df.groupby('Iteration').mean()
al_sl_hybrid_5000_grouped = AL_SL_hybrid_5000_df.groupby('Iteration').mean()
al_sl_hybrid_10000_grouped = AL_SL_hybrid_10000_df.groupby('Iteration').mean()

sl_al_limited_2500_grouped = sl_al_limited_2500_df.groupby('Iteration').mean()
sl_al_limited_5000_grouped = sl_al_limited_5000_df.groupby('Iteration').mean()
sl_al_limited_10000_grouped = sl_al_limited_10000_df.groupby('Iteration').mean()

al_random_2500_grouped = al_random_2500_df.groupby('Iteration').mean()
al_random_5000_grouped = al_random_5000_df.groupby('Iteration').mean()
al_random_10000_grouped = al_random_10000_df.groupby('Iteration').mean()

# Reset index for all grouped dataframes
sl_al_2500_grouped.reset_index(inplace=True)
sl_al_5000_grouped.reset_index(inplace=True)
sl_al_10000_grouped.reset_index(inplace=True)

al_2500_grouped.reset_index(inplace=True)
al_5000_grouped.reset_index(inplace=True)
al_10000_grouped.reset_index(inplace=True)

al_sl_hybrid_2500_grouped.reset_index(inplace=True)
al_sl_hybrid_5000_grouped.reset_index(inplace=True)
al_sl_hybrid_10000_grouped.reset_index(inplace=True)

sl_al_limited_2500_grouped.reset_index(inplace=True)
sl_al_limited_5000_grouped.reset_index(inplace=True)
sl_al_limited_10000_grouped.reset_index(inplace=True)

al_random_2500_grouped.reset_index(inplace=True)
al_random_5000_grouped.reset_index(inplace=True)
al_random_10000_grouped.reset_index(inplace=True)

# %%
plt.figure(figsize=(10, 6))

# plt.plot(sl_al_limited_2500_grouped['Iteration'], sl_al_limited_2500_grouped['Accuracy'], label='SL+AL z ograniczeniem 2500', marker='o')
plt.plot(al_2500_grouped['Iteration'], al_2500_grouped['Accuracy'], label='AL', marker='s')
plt.plot(sl_al_2500_grouped['Iteration'], sl_al_2500_grouped['Accuracy'], label='SL+AL (bez ograniczeń)', marker='x')
# plt.plot(al_random_2500_grouped['Iteration'], al_random_2500_grouped['Accuracy'], label='Random AL 2500', marker='d')
# plt.plot(al_sl_hybrid_2500_grouped['Iteration'], al_sl_hybrid_2500_grouped['Accuracy'], label='Równoległe SL+AL', marker='^')

plt.xlabel('Iteracja')
plt.ylabel('Dokładność (%)')
plt.title('Wpływ iteracji na dokładność modelu dla budżetu 2500')
plt.legend()
plt.grid(True)

plt.show()

# %%
sl_al_limited_2500_grouped_filtered
# Out:
#     Iteration  Fold  Self-Labeled Samples  New Oracle Samples  Used Budget  \
# 0           0   3.0                   0.0                 0.0        500.0
# 1           1   3.0                 200.0                 0.0        500.0
# 2           2   3.0                 120.0                80.0        580.0
# 3           3   3.0                  80.0               120.0        700.0
# 4           4   3.0                 120.0                80.0        780.0
# 5           5   3.0                 120.0                40.0        820.0
# 6           6   3.0                  40.0               120.0        940.0
# 7           7   3.0                  80.0                40.0        980.0
# 8           8   3.0                 160.0                40.0       1020.0
# 9           9   3.0                  40.0               120.0       1140.0
# 10         10   3.0                 160.0                40.0       1180.0
#
# ...

# %%
plt.figure(figsize=(10, 6))

# Filter dataframes to include only the first 10 iterations
sl_al_limited_2500_grouped_filtered = sl_al_limited_2500_grouped[sl_al_limited_2500_grouped['Iteration'] <= 10]
al_2500_grouped_filtered = al_2500_grouped[al_2500_grouped['Iteration'] <= 10]
sl_al_2500_grouped_filtered = sl_al_2500_grouped[sl_al_2500_grouped['Iteration'] <= 10]
al_random_2500_grouped_filtered = al_random_2500_grouped[al_random_2500_grouped['Iteration'] <= 10]
al_sl_hybrid_2500_grouped_filtered = al_sl_hybrid_2500_grouped[al_sl_hybrid_2500_grouped['Iteration'] <= 10]

# Plot the filtered data
# plt.plot(sl_al_limited_2500_grouped_filtered['Iteration'], sl_al_limited_2500_grouped_filtered['% Labeled'], label='SL+AL z ograniczeniem 2500', marker='o')
plt.plot(al_2500_grouped_filtered['Iteration'], al_2500_grouped_filtered['% Labeled'], label='AL', marker='s')
plt.plot(sl_al_2500_grouped_filtered['Iteration'], sl_al_2500_grouped_filtered['% Labeled'], label='SL+AL (bez ograniczeń)', marker='x')
# plt.plot(al_random_2500_grouped_filtered['Iteration'], al_random_2500_grouped_filtered['% Labeled'], label='Random AL 2500', marker='d')
# plt.plot(al_sl_hybrid_2500_grouped_filtered['Iteration'], al_sl_hybrid_2500_grouped_filtered['% Labeled'], label='Równoległe SL+AL', marker='^')

plt.xlabel('Iteracja')
plt.ylabel('Ilości nadanych etykiet/ilości wszystkich próbek (%)')
plt.title('Szybkości etykietowania danych dla budżetu 2500')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))

# Filter dataframes to include only the first 10 iterations
sl_al_limited_2500_grouped_filtered = sl_al_limited_2500_grouped[sl_al_limited_2500_grouped['Iteration'] <= 10]
al_2500_grouped_filtered = al_2500_grouped[al_2500_grouped['Iteration'] <= 10]
sl_al_2500_grouped_filtered = sl_al_2500_grouped[sl_al_2500_grouped['Iteration'] <= 10]
al_random_2500_grouped_filtered = al_random_2500_grouped[al_random_2500_grouped['Iteration'] <= 10]
al_sl_hybrid_2500_grouped_filtered = al_sl_hybrid_2500_grouped[al_sl_hybrid_2500_grouped['Iteration'] <= 10]

# Plot the filtered data
plt.plot(sl_al_limited_2500_grouped_filtered['Iteration'], sl_al_limited_2500_grouped_filtered['% Labeled'], label='SL+AL z ograniczeniem 2500', marker='o')
plt.plot(al_2500_grouped_filtered['Iteration'], al_2500_grouped_filtered['% Labeled'], label='AL', marker='s')
plt.plot(sl_al_2500_grouped_filtered['Iteration'], sl_al_2500_grouped_filtered['% Labeled'], label='SL+AL (bez ograniczeń)', marker='x')
plt.plot(al_random_2500_grouped_filtered['Iteration'], al_random_2500_grouped_filtered['% Labeled'], label='Random AL 2500', marker='d')
plt.plot(al_sl_hybrid_2500_grouped_filtered['Iteration'], al_sl_hybrid_2500_grouped_filtered['% Labeled'], label='Równoległe SL+AL', marker='^')

plt.xlabel('Number of Iterations')
plt.ylabel('% of Labeled Data')
plt.title('Comparison of % Labeled Data Across Iterations (Limited to 10 Iterations)')
plt.legend()
plt.grid(True)

plt.show()

# %%
al_sl_hybrid_2500 = AL_SL_hybrid_2500_df.groupby('Iteration').mean()
al_sl_hybrid_5000 = AL_SL_hybrid_5000_df.groupby('Iteration').mean()
al_sl_hybrid_10000 = AL_SL_hybrid_10000_df.groupby('Iteration').mean()


sl_al_2500_grouped = sl_al_2500_df.groupby('Used Budget').mean()
sl_al_5000_grouped = sl_al_5000_df.groupby('Used Budget').mean()
sl_al_10000_grouped = sl_al_10000_df.groupby('Used Budget').mean()

al_2500_grouped = al_2500_df.groupby('Iteration').mean()
al_5000_grouped = al_5000_df.groupby('Iteration').mean()
al_10000_grouped = al_10000_df.groupby('Iteration').mean()


al_sl_limited_2500 = sl_al_limited_2500_df.groupby('Used Budget').mean()
al_sl_limited_5000 = sl_al_limited_5000_df.groupby('Used Budget').mean()
al_sl_limited_10000 = sl_al_limited_10000_df.groupby('Used Budget').mean()

al_random_2500_df = al_random_2500_df.groupby('Iteration').mean()
al_random_5000_df = al_random_5000_df.groupby('Iteration').mean()
al_random_10000_df = al_random_10000_df.groupby('Iteration').mean()

sl_al_2500_grouped.reset_index(inplace=True)
sl_al_5000_grouped.reset_index(inplace=True)
sl_al_10000_grouped.reset_index(inplace=True)

al_2500_grouped.reset_index(inplace=True)
al_5000_grouped.reset_index(inplace=True)
al_10000_grouped.reset_index(inplace=True)

al_sl_hybrid_2500.reset_index(inplace=True)
al_sl_hybrid_5000.reset_index(inplace=True)
al_sl_hybrid_10000.reset_index(inplace=True)

al_sl_limited_2500.reset_index(inplace=True)
al_sl_limited_5000.reset_index(inplace=True)    
al_sl_limited_10000.reset_index(inplace=True)

al_random_2500_df.reset_index(inplace=True)
al_random_5000_df.reset_index(inplace=True) 
al_random_10000_df.reset_index(inplace=True)

# %% [markdown]
# # B=2500

# %%
plt.figure(figsize=(10, 6))

plt.plot(al_sl_limited_2500['Used Budget'], al_sl_limited_2500['Accuracy'], label='SL+AL', marker='o')
plt.plot(al_2500_grouped['Total Labeled'], al_2500_grouped['Accuracy'], label='AL', marker='s')
plt.plot(sl_al_2500_grouped['Used Budget'], sl_al_2500_grouped['Accuracy'], label='SL+AL (bez ograniczeń)', marker='x')
plt.plot(al_random_2500_df['Used Budget'], al_random_2500_df['Accuracy'], label='Losowe AL', marker='d')
plt.plot(al_sl_hybrid_2500['Used Budget'], al_sl_hybrid_2500['Accuracy'], label='Równoległe SL+AL', marker='^')

plt.xlabel('Użyty Budżet (w próbkach)')
plt.ylabel('Dokładność (%)')
plt.title('Porównanie metod dla budżetu 2500')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # B=5000

# %%
plt.figure(figsize=(10, 6))

plt.plot(al_sl_limited_5000['Used Budget'], al_sl_limited_5000['Accuracy'], label='SL+AL', marker='o')
plt.plot(al_5000_grouped['Total Labeled'], al_5000_grouped['Accuracy'], label='AL', marker='s')
plt.plot(sl_al_5000_grouped['Used Budget'], sl_al_5000_grouped['Accuracy'], label='SL+AL (bez ograniczeń)', marker='x')
plt.plot(al_random_5000_df['Used Budget'], al_random_5000_df['Accuracy'], label='Losowe AL', marker='d')
plt.plot(al_sl_hybrid_5000['Used Budget'], al_sl_hybrid_5000['Accuracy'], label='Równoległe SL+AL', marker='^')

plt.xlabel('Użyty Budżet (w próbkach)')
plt.ylabel('Dokładność (%)')
plt.title('Porównanie metod dla budżetu 5000')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # B=10000

# %%
plt.figure(figsize=(10, 6))

plt.plot(al_sl_limited_10000['Used Budget'], al_sl_limited_10000['Accuracy'], label='SL+AL', marker='o')
plt.plot(al_10000_grouped['Total Labeled'], al_10000_grouped['Accuracy'], label='AL', marker='s')
plt.plot(sl_al_10000_grouped['Used Budget'], sl_al_10000_grouped['Accuracy'], label='SL+AL (bez ograniczeń)', marker='x')
plt.plot(al_random_10000_df['Used Budget'], al_random_10000_df['Accuracy'], label='Losowe AL', marker='d')
plt.plot(al_sl_hybrid_10000['Used Budget'], al_sl_hybrid_10000['Accuracy'], label='Równoległe SL+AL', marker='^')

# Add labels, legend, and title
plt.xlabel('Użyty Budżet (w próbkach)')
plt.ylabel('Dokładność (%)')
plt.title('Porównanie metod dla budżetu 10000')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(sl_al_2500_grouped['Used Budget'], sl_al_2500_grouped['Accuracy'], label='SL AL 2500', marker='o')
plt.plot(al_2500_grouped['Total Labeled'], al_2500_grouped['Accuracy'], label='AL 2500', marker='s')
plt.plot(al_sl_hybrid_2500['Used Budget'], al_sl_hybrid_2500['Accuracy'], label='HYBRID SL AL 2500', marker='^')
plt.plot(al_sl_limited_2500['Used Budget'], al_sl_limited_2500['Accuracy'], label='SL AL 2500 limited', marker='x')

# Add labels, legend, and title
plt.xlabel('Used Budget')
plt.ylabel('Accuracy')
plt.title('Comparison of SL AL 2500 and AL 2500')
plt.legend()
plt.grid(True)
plt.show()

# %%
sl_al_2500_grouped
# Out:
#    Used Budget      Fold  Iteration  Self-Labeled Samples  New Oracle Samples  \
# 0          500  2.823529   1.235294           7596.705882                 0.0
# 1         2000  5.000000   3.000000              0.000000             11670.0
# 2         2100  4.000000   3.000000              0.000000             11867.0
# 3         2200  3.000000   3.000000              0.000000             12436.0
# 4         2300  2.000000   4.000000              0.000000              6349.0
# 5         2400  1.000000   4.000000              0.000000              6309.0
#
#    Total Labeled  Total Unlabeled  % Labeled   Accuracy  F1 Score  Precision  \
# 0   13889.176471     26110.823529  34.722353  32.058824  0.305394   0.360259
# 1   29599.000000     10401.000000  74.000000  31.000000  0.297300   0.398300
# 2   29826.000000     10174.000000  74.560000  39.000000  0.387200   0.467500
# 3   31573.000000      8427.000000  78.930000  36.000000  0.323300   0.437300
# ...

# %%
plt.figure(figsize=(10, 6))

plt.plot(sl_al_2500_grouped['Used Budget'], sl_al_2500_grouped['Accuracy'], label='SL AL 2500', marker='o')
plt.plot(al_2500_grouped['Total Labeled'], al_2500_grouped['Accuracy'], label='AL 2500', marker='s')
plt.plot(al_sl_hybrid_2500['Used Budget'], al_sl_hybrid_2500['Accuracy'], label='HYBRID SL AL 2500', marker='^')
plt.plot(al_sl_limited_2500['Used Budget'], al_sl_limited_2500['Accuracy'], label='SL AL 2500 limited', marker='x')

# Add labels, legend, and title
plt.xlabel('Used Budget')
plt.ylabel('Accuracy')
plt.title('Comparison of SL AL 2500 and AL 2500')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# When the SL with AL is used, without limtited number of samples, the budget is used before 10th iteration. Too much data are sent to oracle per one iteration.
